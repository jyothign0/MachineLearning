# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('loan_prediction.csv')
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.shape
# Out:
# (614, 13)

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df['Loan_Status'].value_counts()
# Out:
# Y    422
# N    192
# Name: Loan_Status, dtype: int64

# %%
df['Loan_Status'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['Loan_Status'].value_counts()/len(df)
# Out:
# Y    0.687296
# N    0.312704
# Name: Loan_Status, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
#loan id not required so we can drop
df.drop(['Loan_ID'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             601 non-null    object
#  1   Married            611 non-null    object
#  2   Dependents         599 non-null    object
#  3   Education          614 non-null    object
#  4   Self_Employed      582 non-null    object
#  5   ApplicantIncome    614 non-null    int64
#  6   CoapplicantIncome  614 non-null    float64
#  7   LoanAmount         592 non-null    float64
#  8   Loan_Amount_Term   600 non-null    float64
#  9   Credit_History     564 non-null    float64
#  10  Property_Area      614 non-null    object
#  11  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(7)
# memory usage: 57.7+ KB

# %%
#check for missing values
df.isnull().sum()
# Out:
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
# values in gender for each class
df['Gender'].value_counts()
# Out:
# Male      489
# Female    112
# Name: Gender, dtype: int64

# %%
df.loc[df['Gender'].isnull()]
# Out:
#     Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 23     NaN     Yes          2  Not Graduate            No             3365
# 126    NaN     Yes         3+      Graduate            No            23803
# 171    NaN     Yes         3+      Graduate            No            51763
# 188    NaN     Yes          0      Graduate           Yes              674
# 314    NaN     Yes          0      Graduate            No             2473
# 334    NaN     Yes          1      Graduate           Yes             9833
# 460    NaN     Yes          0      Graduate           Yes             2083
# 467    NaN     Yes          0      Graduate            No            16692
# 477    NaN     Yes          2      Graduate            No             2873
# 507    NaN      No          0      Graduate            No             3583
# 576    NaN     Yes          0      Graduate            No             3087
# ...

# %%
df['Gender'].fillna('Male',inplace=True)

# %%
df.loc[df['Credit_History'].isnull()]
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 16     Male      No          1  Not Graduate            No             3596
# 24     Male     Yes          1      Graduate           NaN             3717
# 30     Male     Yes          1      Graduate           NaN             4166
# 42     Male     Yes          0      Graduate            No             2400
# 79     Male     Yes         3+  Not Graduate           Yes             3333
# 83     Male     Yes          0      Graduate            No             6000
# 86     Male     Yes          2  Not Graduate            No             3333
# 95     Male      No          0      Graduate           NaN             6782
# 117    Male     Yes          1      Graduate            No             2214
# 125  Female      No          0      Graduate            No             3692
# 129    Male     Yes          0      Graduate            No             6080
# ...

# %%
df.dropna(axis=0,inplace=True)

# %%
df.shape
# Out:
# (492, 12)

# %%
df['Dependents'].value_counts()
# Out:
# 0     280
# 2      87
# 1      81
# 3+     44
# Name: Dependents, dtype: int64

# %%
df['Dependents']=df['Dependents'].replace('3+',3)
df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 1   Male     Yes          1      Graduate            No             4583
# 2   Male     Yes          0      Graduate           Yes             3000
# 3   Male     Yes          0  Not Graduate            No             2583
# 4   Male      No          0      Graduate            No             6000
# 5   Male     Yes          2      Graduate           Yes             5417
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
# 5             4196.0       267.0             360.0             1.0
#
#   Property_Area Loan_Status
# 1         Rural           N
# 2         Urban           Y
# 3         Urban           Y
# ...

# %%
df['Dependents']=df['Dependents'].astype('int64')

# %%
#convert to 0 and 1 (Numeric Encoding)
#binary encoder, target encoder-not used in real time, label encoding
new_df=pd.get_dummies(df,drop_first=True)
new_df.head()
# Out:
#    Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 1           1             4583             1508.0       128.0
# 2           0             3000                0.0        66.0
# 3           0             2583             2358.0       120.0
# 4           0             6000                0.0       141.0
# 5           2             5417             4196.0       267.0
#
#    Loan_Amount_Term  Credit_History  Gender_Male  Married_Yes  \
# 1             360.0             1.0            1            1
# 2             360.0             1.0            1            1
# 3             360.0             1.0            1            1
# 4             360.0             1.0            1            0
# 5             360.0             1.0            1            1
#
#    Education_Not Graduate  Self_Employed_Yes  Property_Area_Semiurban  \
# 1                       0                  0                        0
# 2                       0                  1                        0
# ...

# %%
#apply MinMaxScaling on Numeric features
df.head()
# Out:
#   Gender Married  Dependents     Education Self_Employed  ApplicantIncome  \
# 1   Male     Yes           1      Graduate            No             4583
# 2   Male     Yes           0      Graduate           Yes             3000
# 3   Male     Yes           0  Not Graduate            No             2583
# 4   Male      No           0      Graduate            No             6000
# 5   Male     Yes           2      Graduate           Yes             5417
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
# 5             4196.0       267.0             360.0             1.0
#
#   Property_Area Loan_Status
# 1         Rural           N
# 2         Urban           Y
# 3         Urban           Y
# ...

# %%
num_cols=df.select_dtypes(['int64','float64']).drop(['Dependents','Credit_History'],axis=1)
num_cols
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# 5               5417             4196.0       267.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
# [492 rows x 4 columns]

# %%
num_cols.columns
# Out:
# Index(['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term'],
#       dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler
M_sc=MinMaxScaler()
new_df[num_cols.columns]=M_sc.fit_transform(num_cols)  #we have scaled between 0 and 1 i.e. standardized

# %%
new_df.head()
# Out:
#    Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 1           1         0.054830           0.044567    0.172214
# 2           0         0.035250           0.000000    0.082489
# 3           0         0.030093           0.069687    0.160637
# 4           0         0.072356           0.000000    0.191027
# 5           2         0.065145           0.124006    0.373372
#
#    Loan_Amount_Term  Credit_History  Gender_Male  Married_Yes  \
# 1           0.72973             1.0            1            1
# 2           0.72973             1.0            1            1
# 3           0.72973             1.0            1            1
# 4           0.72973             1.0            1            0
# 5           0.72973             1.0            1            1
#
#    Education_Not Graduate  Self_Employed_Yes  Property_Area_Semiurban  \
# 1                       0                  0                        0
# 2                       0                  1                        0
# ...

# %%
x=new_df.drop('Loan_Status_Y',axis=1)
y=new_df['Loan_Status_Y']

# %%
#spilt the data for training and testing
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8, random_state=42)

# %%
print(x_test.shape,y_test.shape)
# Out:
# (99, 12) (99,)

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_model=LogisticRegression()
log_model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
tr_pred=log_model.predict(x_train)
ts_pred=log_model.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score,precision_score

# %%
y_train.value_counts()
# Out:
# 1    272
# 0    121
# Name: Loan_Status_Y, dtype: int64

# %%
sns.heatmap(confusion_matrix(y_train,tr_pred),annot=True,fmt='d')
plt.show()

# %%
print('Training Accuracy score -',accuracy_score(y_train,tr_pred))
print('Training Recall score -',recall_score(y_train,tr_pred))
print('Training Precision score -',precision_score(y_train,tr_pred))
# Out:
# Training Accuracy score - 0.811704834605598
# Training Recall score - 0.9816176470588235
# Training Precision score - 0.7946428571428571

# %%
#do it for testing
print('Testing Accuracy score -',accuracy_score(y_test,ts_pred))
print('Testing Recall score -',recall_score(y_test,ts_pred))
print('Testing Precision score -',precision_score(y_test,ts_pred))
# Out:
# Testing Accuracy score - 0.797979797979798
# Testing Recall score - 0.9701492537313433
# Testing Precision score - 0.7831325301204819
